# %% [markdown]
# # 깃허브
#
#
# 4) 깃의 소유주 확인&변경
# - git config --list
#
# 5) github 회원가입 : 계정정보 값으로 입력 : https//github.com/
# - git : 나의 로컬컴퓨터에서 버전 관리 툴
# - github : 나의 로컬컴퓨터에서 관리하고 있는 버전을 타인과 공유해서 함께 사용하고자 할 때, 혹은 내가 사용하고 있는 디바이스가 2대 이상인 경우, A에서도 데이터관리, B에서도 데이터관리
# - repository : github < project에 따른 개별 폴더
# - user.email : jihuni00c@gmail.com
# - user.name : jihuni00c
# - 터미널 재접속 > 관리자모드 : 전역(global)세팅
# - git config --global user.name "jihuni00c"
# - git config --global user.email "jihuni00c@gmail.com"
#
# 6) git commit & push
# - cd "현재나의 루트폴더" 이동
# - git 초기화 : git init
# - staging area : 데이터 전송 : got add .
